# %%
import pandas as pd
import numpy as np
import os
import re
import openpyxl
from pymongo import MongoClient
import json

folder_paths = {
    'Flipkart': r'D:\E-commerce\Automation Source\Flipkart',
    'Amazon': r'D:\E-commerce\Automation Source\Amazon',
    'Meesho_Invoice': r'D:\E-commerce\Automation Source\Meesho'
}

def get_file_paths(folder, ext, pattern=None, exclude_pattern=None):
    files = [
        f for f in os.listdir(folder)
        if f.endswith(ext)
        and (pattern is None or re.search(pattern, f))
        and (exclude_pattern is None or not re.search(exclude_pattern, f))
    ]
    return [os.path.join(folder, f) for f in files]

def read_excel_files(file_paths, sheet_name):
    return pd.concat([pd.read_excel(fp, sheet_name=sheet_name) for fp in file_paths], ignore_index=True)

def read_csv_files(file_paths):
    return pd.concat([pd.read_csv(fp) for fp in file_paths], ignore_index=True)

flipkart_files = get_file_paths(folder_paths['Flipkart'], '.xlsx',exclude_pattern=None)
flipkart_data = read_excel_files(flipkart_files, sheet_name='Sales Report')

amazon_b2b_files = get_file_paths(folder_paths['Amazon'], '.csv', 'B2B',exclude_pattern=None)
amazon_b2c_files = get_file_paths(folder_paths['Amazon'], '.csv', 'B2C',exclude_pattern=None)
amazon_b2b_data = read_csv_files(amazon_b2b_files)
amazon_b2c_data = read_csv_files(amazon_b2c_files)

meesho_invoice_files = get_file_paths(folder_paths['Meesho_Invoice'], '.xlsx', 'Tax_invoice_details',exclude_pattern=None)
meesho_forward_files = get_file_paths(folder_paths['Meesho_Invoice'], '.xlsx', 'Forward',exclude_pattern=None)
meesho_reverse_files = get_file_paths(folder_paths['Meesho_Invoice'], '.xlsx', 'Reverse',exclude_pattern='Waiver')



meesho_invoice_data = read_excel_files(meesho_invoice_files, sheet_name='Invoice_Info')
meesho_forward_data = read_excel_files(meesho_forward_files, sheet_name='282410')
meesho_reverse_data = read_excel_files(meesho_reverse_files, sheet_name='282410')

def get_financial_year(date):
    year = date.year
    if date.month >= 4:
        fy_start_year = year
    else: 
        fy_start_year = year - 1
    fy_end_year = fy_start_year + 1
    return f"{fy_start_year}-{str(fy_end_year)[2:]}"

def add_financial_year(df, date_col):
    df[date_col] = pd.to_datetime(df[date_col])
    df['Financial Year'] = df[date_col].apply(lambda x: f"{x.year if x.month >= 4 else x.year - 1}-{(x.year if x.month >= 4 else x.year - 1) + 1 - 2000}")
    return df

flipkart_data = add_financial_year(flipkart_data, 'Buyer Invoice Date')
amazon_b2b_data = add_financial_year(amazon_b2b_data, 'Invoice Date')
amazon_b2c_data = add_financial_year(amazon_b2c_data, 'Invoice Date')

Flipkart_Tax_report = pd.DataFrame({
    'Marketplace': 'FLIPKART',
    'Invoice Number': flipkart_data['Buyer Invoice ID'],
    'Invoice Date': flipkart_data['Buyer Invoice Date'],
    'Party Name': 'NA',
    'GSTN': 'NA',
    'Period': pd.to_datetime(flipkart_data['Buyer Invoice Date']).dt.strftime('%b'),
    'FY': flipkart_data['Financial Year'],
    'Nature': 'B2C',
    'Transaction Type': flipkart_data['Event Sub Type'],
    'Destination': flipkart_data['Customer\'s Delivery State'],
    'HSN Code': flipkart_data['HSN Code'],
    'Qty': flipkart_data['Item Quantity'],
    'Taxable Value': flipkart_data['Taxable Value (Final Invoice Amount -Taxes)'],
    'GST Rate': (flipkart_data['IGST Rate'] + flipkart_data['CGST Rate'] + flipkart_data['SGST Rate (or UTGST as applicable)']) / 100,
    'IGST': flipkart_data['IGST Amount'],
    'CGST': flipkart_data['CGST Amount'],
    'SGST': flipkart_data['SGST Amount (Or UTGST as applicable)'],
    'Invoice Value': flipkart_data['Buyer Invoice Amount'],
    'TCS': flipkart_data['Total TCS Deducted'],
})

B2B_Amazon_Tax_Report = pd.DataFrame({
    'Marketplace': 'AMAZON',
    'Invoice Number': amazon_b2b_data['Invoice Number'],
    'Invoice Date': amazon_b2b_data['Invoice Date'],
    'Party Name': amazon_b2b_data['Buyer Name'],
    'GSTN': amazon_b2b_data['Customer Bill To Gstid'],
    'Period': pd.to_datetime(amazon_b2b_data['Invoice Date']).dt.strftime('%b'),
    'FY': amazon_b2b_data['Financial Year'],
    'Nature': 'B2B',
    'Transaction Type': amazon_b2b_data['Transaction Type'],
    'Destination': amazon_b2b_data['Ship To State'],
    'HSN Code': amazon_b2b_data['Hsn/sac'],
    'Qty': amazon_b2b_data['Quantity'],
    'Taxable Value': amazon_b2b_data['Tax Exclusive Gross'],
    'GST Rate': amazon_b2b_data['Igst Rate'] + amazon_b2b_data['Cgst Rate'] + amazon_b2b_data['Sgst Rate'] + amazon_b2b_data['Utgst Rate'],
    'IGST': amazon_b2b_data['Tax Exclusive Gross'] * amazon_b2b_data['Igst Rate'],
    'CGST': amazon_b2b_data['Tax Exclusive Gross'] * amazon_b2b_data['Cgst Rate'],
    'SGST': amazon_b2b_data['Tax Exclusive Gross'] * (amazon_b2b_data['Sgst Rate'] + amazon_b2b_data['Utgst Rate']),
    'Invoice Value': amazon_b2b_data['Invoice Amount'],
    'TCS': amazon_b2b_data['Tax Exclusive Gross'] * 0.01
})

B2C_Amazon_Tax_Report = pd.DataFrame({
    'Marketplace': 'AMAZON',
    'Invoice Number': amazon_b2c_data['Invoice Number'],
    'Invoice Date': amazon_b2c_data['Invoice Date'],
    'Party Name': 'NA',
    'GSTN': 'NA',
    'Period': pd.to_datetime(amazon_b2c_data['Invoice Date']).dt.strftime('%b'),
    'FY': amazon_b2c_data['Financial Year'],
    'Nature': 'B2C',
    'Transaction Type': amazon_b2c_data['Transaction Type'],
    'Destination': amazon_b2c_data['Ship To State'],
    'HSN Code': amazon_b2c_data['Hsn/sac'],
    'Qty': amazon_b2c_data['Quantity'],
    'Taxable Value': amazon_b2c_data['Tax Exclusive Gross'],
    'GST Rate': amazon_b2c_data['Igst Rate'] + amazon_b2c_data['Cgst Rate'] + amazon_b2c_data['Sgst Rate'] + amazon_b2c_data['Utgst Rate'],
    'IGST': amazon_b2c_data['Tax Exclusive Gross'] * amazon_b2c_data['Igst Rate'],
    'CGST': amazon_b2c_data['Tax Exclusive Gross'] * amazon_b2c_data['Cgst Rate'],
    'SGST': amazon_b2c_data['Tax Exclusive Gross'] * (amazon_b2c_data['Sgst Rate'] + amazon_b2c_data['Utgst Rate']),
    'Invoice Value': amazon_b2c_data['Invoice Amount'],
    'TCS': amazon_b2c_data['Tax Exclusive Gross'] * 0.01
})


filtered_data_1 = meesho_invoice_data[meesho_invoice_data['Type'] == 'INVOICE']
Meesho_Merged = pd.merge(meesho_forward_data,filtered_data_1,how='left',left_on='sub_order_num',right_on='Suborder No.')
Meesho_Merged
Meesho_Merged['Order Date'] = pd.to_datetime(Meesho_Merged['Order Date'])
Meesho_Merged['Financial Year'] = Meesho_Merged['Order Date'].apply(get_financial_year)
Meesho_Merged_Forward_Report = pd.DataFrame({
    'Marketplace': 'MEESHO',
    'Invoice Number': Meesho_Merged['Invoice No.'],
    'Invoice Date': Meesho_Merged['Order Date'],
    'Party Name': 'NA',
    'GSTN': 'NA',
    'Period': pd.to_datetime(Meesho_Merged['Order Date']).dt.strftime('%b'),
    'FY': Meesho_Merged['Financial Year'],
    'Nature': 'B2C',
    'Transaction Type': Meesho_Merged['order_status'],
    'Destination': Meesho_Merged['end_customer_state_new'],
    'HSN Code': Meesho_Merged['HSN'],
    'Qty': Meesho_Merged['quantity'],
    'Taxable Value': Meesho_Merged['tcs_taxable_amount'],
    'GST Rate': Meesho_Merged['gst_rate'] / 100,
    'IGST': 
    Meesho_Merged.apply(
    lambda row: row['tcs_taxable_amount'] * (row['gst_rate'] / 100) if row['end_customer_state_new'] != 'Tamil Nadu' else 0,
    axis=1),
    'CGST': 
    Meesho_Merged.apply(
    lambda row: row['tcs_taxable_amount'] * ((row['gst_rate']  / 100) / 2) if row['end_customer_state_new'] == 'Tamil Nadu' else 0,
    axis=1),
    'SGST': 
    Meesho_Merged.apply(
    lambda row: row['tcs_taxable_amount'] * ((row['gst_rate']  / 100) / 2) if row['end_customer_state_new'] == 'Tamil Nadu' else 0,
    axis=1),
    'Invoice Value': Meesho_Merged['meesho_price'],
    'TCS': Meesho_Merged['tcs_taxable_amount'] * 0.01
})

filtered_data_2 = meesho_invoice_data[meesho_invoice_data['Type'] == 'CREDIT INVOICE']
Meesho_Merged_1 = pd.merge(meesho_reverse_data,filtered_data_2,how='left',left_on='sub_order_num',right_on='Suborder No.')
Meesho_Merged_1
Meesho_Merged_1['Order Date'] = pd.to_datetime(Meesho_Merged_1['Order Date'])
Meesho_Merged_1['Financial Year'] = Meesho_Merged_1['Order Date'].apply(get_financial_year)
Meesho_Merged_1_Reverse_Report = pd.DataFrame({
    'Marketplace': 'MEESHO',
    'Invoice Number': Meesho_Merged_1['Invoice No.'],
    'Invoice Date': Meesho_Merged_1['Order Date'],
    'Party Name': 'NA',
    'GSTN': 'NA',
    'Period': pd.to_datetime(Meesho_Merged_1['Order Date']).dt.strftime('%b'),
    'FY': Meesho_Merged_1['Financial Year'],
    'Nature': 'B2C',
    'Transaction Type': Meesho_Merged_1['order_status'],
    'Destination': Meesho_Merged_1['end_customer_state_new'],
    'HSN Code': Meesho_Merged_1['HSN'],
    'Qty': Meesho_Merged_1['quantity'],
    'Taxable Value': Meesho_Merged_1['tcs_taxable_amount'],
    'GST Rate': Meesho_Merged_1['gst_rate'] / 100,
    'IGST': 
    Meesho_Merged.apply(
    lambda row: row['tcs_taxable_amount'] * (row['gst_rate'] / 100) if row['end_customer_state_new'] != 'Tamil Nadu' else 0,
    axis=1),
    'CGST': 
    Meesho_Merged.apply(
    lambda row: row['tcs_taxable_amount'] * ((row['gst_rate']  / 100) / 2) if row['end_customer_state_new'] == 'Tamil Nadu' else 0,
    axis=1),
    'SGST': 
    Meesho_Merged.apply(
    lambda row: row['tcs_taxable_amount'] * ((row['gst_rate']  / 100) / 2) if row['end_customer_state_new'] == 'Tamil Nadu' else 0,
    axis=1),
    'Invoice Value': Meesho_Merged_1['meesho_price'],
    'TCS': Meesho_Merged_1['tcs_taxable_amount'] * 0.01
})

Final_Report = pd.concat([Flipkart_Tax_report, B2B_Amazon_Tax_Report, B2C_Amazon_Tax_Report, Meesho_Merged_Forward_Report, Meesho_Merged_1_Reverse_Report], axis=0, ignore_index=True)

Final_Tax_Report = Final_Report[Final_Report[['Invoice Value', 'Invoice Date']].notna().all(axis=1)]

# %%
Final_Tax_Report
# Out:
#      Marketplace    Invoice Number        Invoice Date Party Name GSTN Period  \
# 0       FLIPKART  FAHTK32200000001 2021-06-15 00:00:00         NA   NA    Jun
# 1       FLIPKART  FAHTK32200000002 2021-06-20 00:00:00         NA   NA    Jun
# 2       FLIPKART  FAHTK32200000003 2021-06-20 00:00:00         NA   NA    Jun
# 3       FLIPKART  RAF0JN2200000001 2021-06-22 00:00:00         NA   NA    Jun
# 4       FLIPKART  FAHTK32200000004 2021-06-24 00:00:00         NA   NA    Jun
# ...          ...               ...                 ...        ...  ...    ...
# 4320      MEESHO        dszv725C70 2025-02-02 20:34:29         NA   NA    Feb
# 4321      MEESHO        dszv725C71 2025-02-05 21:40:06         NA   NA    Feb
# 4322      MEESHO        dszv725C73 2025-02-16 19:01:35         NA   NA    Feb
# 4323      MEESHO        dszv725C69 2025-02-01 14:14:32         NA   NA    Feb
# 4324      MEESHO        dszv725C75 2025-02-19 15:21:39         NA   NA    Feb
#
#            FY Nature Transaction Type     Destination  HSN Code  Qty  \
# 0     2021-22    B2C             Sale   Uttar Pradesh  35052000  1.0
# 1     2021-22    B2C             Sale       Telangana  35061000  1.0
# 2     2021-22    B2C             Sale          Odisha  35061000  1.0
# 3     2021-22    B2C           Return       Telangana  35061000  1.0
# 4     2021-22    B2C             Sale         Gujarat  35061000  1.0
# ...       ...    ...              ...             ...       ...  ...
# 4320  2024-25    B2C        Cancelled     MAHARASHTRA    854449  1.0
# 4321  2024-25    B2C        Cancelled     UTTARAKHAND    854449  1.0
# 4322  2024-25    B2C        Cancelled    CHHATTISGARH    854449  1.0
# 4323  2024-25    B2C        Cancelled  MADHYA PRADESH    854449  1.0
# 4324  2024-25    B2C        Cancelled    CHHATTISGARH    854449  1.0
#
#       Taxable Value  GST Rate       IGST  CGST  SGST  Invoice Value        TCS
# 0        174.580000      0.18  31.420000   0.0   0.0          206.0   1.750000
# 1        143.220000      0.18  25.780000   0.0   0.0          169.0   1.430000
# 2        154.240000      0.18  27.760000   0.0   0.0          182.0   1.540000
# 3       -143.220000      0.18 -25.780000   0.0   0.0         -169.0  -1.430000
# 4        191.530000      0.18  34.470000   0.0   0.0          226.0   1.920000
# ...             ...       ...        ...   ...   ...            ...        ...
# 4320    1045.762712      0.18  43.322034   0.0   0.0         1234.0  10.457627
# 4321     500.847458      0.18  43.322034   0.0   0.0          591.0   5.008475
# 4322     544.915254      0.18  43.322034   0.0   0.0          643.0   5.449153
# 4323     466.101695      0.18  43.322034   0.0   0.0          591.0   4.661017
# 4324    1045.762712      0.18  43.322034   0.0   0.0         1234.0  10.457627
#
# [4261 rows x 19 columns]

# %%
export_path_1 = 'final_tax_report.json'
export_path_2 = 'meesho_invoice_data.json'
export_path_3 = 'meesho_forward_data.json'
export_path_4 = 'meesho_reverse_data.json'
Final_Tax_Report.to_json(export_path_1, orient='records', date_format='iso', lines=False)
meesho_invoice_data.to_json(export_path_2, orient='records', date_format='iso', lines=False)
meesho_forward_data.to_json(export_path_3, orient='records', date_format='iso', lines=False)
meesho_reverse_data.to_json(export_path_4, orient='records', date_format='iso', lines=False)

client = MongoClient('mongodb://localhost:27017/')
db = client['Ecommerce_DB']
collections = {
    "Final_Report": Final_Tax_Report,
    "Meesho_Invoice_Report": meesho_invoice_data,
    "Meesho_Forward_Report": meesho_forward_data,
    "Meesho_Reverse_Report": meesho_reverse_data
}

def insert_data_to_mongo(collection_name, df, unique_field=None):
    collection = db[collection_name]
    try:
        # Convert DataFrame to dictionary (list of records)
        data_dict = df.to_dict(orient='records')
        
        # If a unique field is specified, create a unique index on that field or fields
        if unique_field:
            if isinstance(unique_field, list):  # If it's a list, create a composite unique index
                # Create a composite index for multiple fields, each field needs to be specified with direction
                index_fields = [(field, 1) for field in unique_field]
                collection.create_index(index_fields, unique=True)
            else:  # If it's a single field, create a unique index on that field
                collection.create_index([(unique_field, 1)], unique=True)
        
        for data in data_dict:
            # If the unique_field is specified, check if the document with the same value already exists
            if unique_field:
                query = {field: data[field] for field in unique_field}
                if collection.find_one(query):
                    print(f"Document with {query} already exists. Skipping insert.")
                    continue
            
            # Insert the data if it doesn't exist
            collection.insert_one(data)
            print(f"Data inserted successfully: {data}")
        
    except Exception as e:
        print(f"Error inserting data into {collection_name}: {e}")

insert_data_to_mongo("Final_Report", Final_Tax_Report, unique_field=["Invoice Number","Transaction Type","FY"])
# Out:
# Document with {'Invoice Number': 'FAHTK32200000001', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000002', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000003', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000001', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000004', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000005', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000006', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000007', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000008', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000009', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000003', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000011', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000010', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000004', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000005', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000012', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000013', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000006', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000007', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000014', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': '782XR2200000001', 'Transaction Type': 'Return Cancellation', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000008', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000015', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000016', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000018', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000017', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000020', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000019', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000009', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000022', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000021', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000023', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000024', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000010', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000029', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000030', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000011', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000033', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000031', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000032', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000034', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000036', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000037', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000038', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000012', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000039', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000040', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000041', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000043', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000042', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000044', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000015', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000048', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000047', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000016', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000049', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000017', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000018', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000050', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000052', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000051', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000019', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000054', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000055', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000020', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': '782XR2200000002', 'Transaction Type': 'Return Cancellation', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000057', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000056', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000058', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000059', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000060', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000061', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000062', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000063', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000064', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000021', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000065', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000066', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000067', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000068', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000069', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000022', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000070', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000023', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000072', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000071', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000024', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000073', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000075', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000025', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000074', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000026', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000076', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000077', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000078', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000079', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000080', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000028', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000029', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000081', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000083', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000082', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000084', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000032', 'Transaction Type': 'Cancellation', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000031', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000085', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000086', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000088', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000087', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000089', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000090', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000091', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000033', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000092', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000034', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000094', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000093', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000095', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000096', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000097', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000098', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000100', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000099', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000101', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000035', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000102', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000103', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000105', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000104', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000036', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000107', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000106', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000037', 'Transaction Type': 'Cancellation', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000108', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000111', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000110', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000112', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000109', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000038', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000113', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000039', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000114', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000115', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000116', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000040', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000117', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000118', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000041', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000120', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000119', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000122', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000123', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000124', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000121', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000125', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000126', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000127', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000130', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000128', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000129', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000043', 'Transaction Type': 'Cancellation', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000131', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000132', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000045', 'Transaction Type': 'Cancellation', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000133', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000135', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000044', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000136', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000134', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000046', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000137', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': '782XR2200000003', 'Transaction Type': 'Return Cancellation', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000047', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000138', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000139', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000140', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000141', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000142', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000049', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000144', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000143', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000146', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000050', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000147', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000051', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000148', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000052', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000149', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000153', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000150', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000151', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000152', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000053', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000156', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000155', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000154', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000157', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000158', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000159', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000054', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000160', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000002', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000053', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000026', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000025', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000028', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000027', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000030', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000014', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000013', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000046', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000045', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000027', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000145', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32200000035', 'Transaction Type': 'Sale', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000042', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2200000048', 'Transaction Type': 'Return', 'FY': '2021-22'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000001', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000002', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000003', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000001', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000004', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000002', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000007', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000003', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000012', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000013', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000011', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000010', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000023', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000024', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000014', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000018', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000020', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000027', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000021', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000016', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000015', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000017', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000019', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000026', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000005', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000004', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000029', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000007', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000008', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000030', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000009', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000011', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000010', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000033', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000034', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000032', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000035', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000012', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': '782XR2300000001', 'Transaction Type': 'Return Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000038', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000036', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000013', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000041', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000040', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': '782XR2300000002', 'Transaction Type': 'Return Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000014', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000044', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000042', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000015', 'Transaction Type': 'Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000016', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000043', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000018', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000017', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000045', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000046', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000047', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000048', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000049', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000050', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000051', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000052', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000020', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000053', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000022', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000056', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000055', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000058', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000059', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000023', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000060', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000061', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000024', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000063', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000062', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000064', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000065', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000025', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000026', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': '782XR2300000003', 'Transaction Type': 'Return Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000066', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000067', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000069', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000068', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000070', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000027', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000072', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000073', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000071', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000074', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000075', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000076', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000029', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000077', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000079', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000080', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000078', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000030', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000086', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000081', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000082', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000083', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000085', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000087', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000088', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000089', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000031', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000092', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000090', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000091', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000032', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000033', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000094', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000035', 'Transaction Type': 'Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000096', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000093', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000095', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000034', 'Transaction Type': 'Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000097', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000098', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000036', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000037', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000099', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000101', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000100', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000102', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000038', 'Transaction Type': 'Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000103', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000105', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000106', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000104', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000108', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000107', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000040', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000110', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000111', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000041', 'Transaction Type': 'Return', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000112', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000042', 'Transaction Type': 'Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000115', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000113', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000116', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000043', 'Transaction Type': 'Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000114', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'RAF0JN2300000044', 'Transaction Type': 'Cancellation', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000117', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# Document with {'Invoice Number': 'FAHTK32300000119', 'Transaction Type': 'Sale', 'FY': '2022-23'} already exists. Skipping insert.
# ...
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72580', 'Invoice Date': Timestamp('2025-02-17 15:25:01'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Shipped', 'Destination': 'WEST BENGAL', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 544.9152542372882, 'GST Rate': 0.18, 'IGST': 98.08474576271188, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 643.0, 'TCS': 5.449152542372882, '_id': ObjectId('67d4459c2df68cfc0d8ac5ef')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72540', 'Invoice Date': Timestamp('2024-11-09 10:32:09'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Nov', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'TAMIL NADU', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 0.0, 'GST Rate': 0.18, 'IGST': 0.0, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 0.0, 'TCS': 0.0, '_id': ObjectId('67d4459c2df68cfc0d8ac5f0')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72583', 'Invoice Date': Timestamp('2025-02-23 11:45:37'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'GUJARAT', 'HSN Code': 950699, 'Qty': 1.0, 'Taxable Value': 595.7627118644068, 'GST Rate': 0.18, 'IGST': 107.23728813559322, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 703.0, 'TCS': 5.957627118644068, '_id': ObjectId('67d4459c2df68cfc0d8ac5f1')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72582', 'Invoice Date': Timestamp('2025-02-19 15:21:39'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'CHHATTISGARH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 1045.7627118644068, 'GST Rate': 0.18, 'IGST': 188.23728813559322, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 1234.0, 'TCS': 10.457627118644067, '_id': ObjectId('67d4459c2df68cfc0d8ac5f2')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72576', 'Invoice Date': Timestamp('2025-02-10 21:35:41'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Delivered', 'Destination': 'UTTAR PRADESH', 'HSN Code': 391990, 'Qty': 1.0, 'Taxable Value': 852.542372881356, 'GST Rate': 0.18, 'IGST': 153.45762711864407, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 1022.0, 'TCS': 8.52542372881356, '_id': ObjectId('67d4459c2df68cfc0d8ac5f3')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72584', 'Invoice Date': Timestamp('2025-02-23 13:40:43'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'CHHATTISGARH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 544.9152542372882, 'GST Rate': 0.18, 'IGST': 98.08474576271188, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 643.0, 'TCS': 5.449152542372882, '_id': ObjectId('67d4459c2df68cfc0d8ac5f4')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72543', 'Invoice Date': Timestamp('2024-11-13 07:52:34'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Nov', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'TAMIL NADU', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 0.0, 'GST Rate': 0.18, 'IGST': 0.0, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 0.0, 'TCS': 0.0, '_id': ObjectId('67d4459c2df68cfc0d8ac5f5')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72577', 'Invoice Date': Timestamp('2025-02-12 07:42:27'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'CHHATTISGARH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 974.5762711864407, 'GST Rate': 0.18, 'IGST': 175.42372881355934, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 1150.0, 'TCS': 9.745762711864408, '_id': ObjectId('67d4459c2df68cfc0d8ac5f6')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72572', 'Invoice Date': Timestamp('2025-02-01 14:14:32'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'MADHYA PRADESH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 466.1016949152543, 'GST Rate': 0.18, 'IGST': 83.89830508474577, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 591.0, 'TCS': 4.661016949152543, '_id': ObjectId('67d4459c2df68cfc0d8ac5f7')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72542', 'Invoice Date': Timestamp('2024-11-11 13:31:04'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Nov', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'TAMIL NADU', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 0.0, 'GST Rate': 0.18, 'IGST': 0.0, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 0.0, 'TCS': 0.0, '_id': ObjectId('67d4459c2df68cfc0d8ac5f8')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72544', 'Invoice Date': Timestamp('2024-11-13 21:07:32'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Nov', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'JHARKHAND', 'HSN Code': 391990, 'Qty': 1.0, 'Taxable Value': 0.0, 'GST Rate': 0.18, 'IGST': 0.0, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 0.0, 'TCS': 0.0, '_id': ObjectId('67d4459c2df68cfc0d8ac5f9')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72578', 'Invoice Date': Timestamp('2025-02-12 10:24:06'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Delivered', 'Destination': 'BIHAR', 'HSN Code': 391990, 'Qty': 1.0, 'Taxable Value': 235.5932203389831, 'GST Rate': 0.18, 'IGST': 42.406779661016955, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 294.0, 'TCS': 2.355932203389831, '_id': ObjectId('67d4459c2df68cfc0d8ac5fa')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72574', 'Invoice Date': Timestamp('2025-02-05 21:40:06'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'UTTARAKHAND', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 500.8474576271187, 'GST Rate': 0.18, 'IGST': 90.15254237288136, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 591.0, 'TCS': 5.008474576271187, '_id': ObjectId('67d4459c2df68cfc0d8ac5fb')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72581', 'Invoice Date': Timestamp('2025-02-19 11:34:45'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Delivered', 'Destination': 'KARNATAKA', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 536.4406779661017, 'GST Rate': 0.18, 'IGST': 96.5593220338983, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 643.0, 'TCS': 5.364406779661017, '_id': ObjectId('67d4459c2df68cfc0d8ac5fc')}
# Document with {'Invoice Number': 'dszv72530', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv72575', 'Invoice Date': Timestamp('2025-02-08 14:08:51'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'rto', 'Destination': 'HARYANA', 'HSN Code': 391990, 'Qty': 1.0, 'Taxable Value': 522.8813559322034, 'GST Rate': 0.18, 'IGST': 94.11864406779661, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 617.0, 'TCS': 5.228813559322034, '_id': ObjectId('67d4459c2df68cfc0d8ac5fd')}
# Document with {'Invoice Number': 'dszv72570', 'Transaction Type': 'Ordered', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv72566', 'Transaction Type': 'Return', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv72567', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv72565', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv72571', 'Transaction Type': 'Ordered', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv72569', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv72564', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv72568', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C62', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C63', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C65', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C64', 'Transaction Type': 'Return', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C61', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C31', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C30', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C26', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C29', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C27', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C24', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C28', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Document with {'Invoice Number': 'dszv725C25', 'Transaction Type': 'Cancelled', 'FY': '2024-25'} already exists. Skipping insert.
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C67', 'Invoice Date': Timestamp('2025-01-31 13:45:52'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Jan', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'CHHATTISGARH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 1045.7627118644068, 'GST Rate': 0.18, 'IGST': 65.44067796610169, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 1234.0, 'TCS': 10.457627118644067, '_id': ObjectId('67d4459c2df68cfc0d8ac5fe')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C72', 'Invoice Date': Timestamp('2025-02-12 07:42:27'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'CHHATTISGARH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 974.5762711864407, 'GST Rate': 0.18, 'IGST': 186.25423728813558, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 1150.0, 'TCS': 9.745762711864408, '_id': ObjectId('67d4459c2df68cfc0d8ac5ff')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C68', 'Invoice Date': Timestamp('2025-01-31 12:41:45'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Jan', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'JAMMU AND KASHMIR', 'HSN Code': 391990, 'Qty': 1.0, 'Taxable Value': 670.3389830508474, 'GST Rate': 0.18, 'IGST': 97.01694915254238, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 799.0, 'TCS': 6.703389830508475, '_id': ObjectId('67d4459c2df68cfc0d8ac600')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C74', 'Invoice Date': Timestamp('2025-02-08 14:08:51'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'rto', 'Destination': 'HARYANA', 'HSN Code': 391990, 'Qty': 1.0, 'Taxable Value': 522.8813559322034, 'GST Rate': 0.18, 'IGST': 187.01694915254237, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 617.0, 'TCS': 5.228813559322034, '_id': ObjectId('67d4459c2df68cfc0d8ac601')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C66', 'Invoice Date': Timestamp('2025-01-27 19:07:11'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Jan', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'WEST BENGAL', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 520.3389830508474, 'GST Rate': 0.18, 'IGST': 65.7457627118644, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 644.0, 'TCS': 5.203389830508475, '_id': ObjectId('67d4459c2df68cfc0d8ac602')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C70', 'Invoice Date': Timestamp('2025-02-02 20:34:29'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'MAHARASHTRA', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 1045.7627118644068, 'GST Rate': 0.18, 'IGST': 43.32203389830508, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 1234.0, 'TCS': 10.457627118644067, '_id': ObjectId('67d4459c2df68cfc0d8ac603')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C71', 'Invoice Date': Timestamp('2025-02-05 21:40:06'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'UTTARAKHAND', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 500.8474576271187, 'GST Rate': 0.18, 'IGST': 43.32203389830508, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 591.0, 'TCS': 5.008474576271187, '_id': ObjectId('67d4459c2df68cfc0d8ac604')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C73', 'Invoice Date': Timestamp('2025-02-16 19:01:35'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'CHHATTISGARH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 544.9152542372882, 'GST Rate': 0.18, 'IGST': 43.32203389830508, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 643.0, 'TCS': 5.449152542372882, '_id': ObjectId('67d4459c2df68cfc0d8ac605')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C69', 'Invoice Date': Timestamp('2025-02-01 14:14:32'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'MADHYA PRADESH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 466.1016949152543, 'GST Rate': 0.18, 'IGST': 43.32203389830508, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 591.0, 'TCS': 4.661016949152543, '_id': ObjectId('67d4459c2df68cfc0d8ac606')}
# Data inserted successfully: {'Marketplace': 'MEESHO', 'Invoice Number': 'dszv725C75', 'Invoice Date': Timestamp('2025-02-19 15:21:39'), 'Party Name': 'NA', 'GSTN': 'NA', 'Period': 'Feb', 'FY': '2024-25', 'Nature': 'B2C', 'Transaction Type': 'Cancelled', 'Destination': 'CHHATTISGARH', 'HSN Code': 854449, 'Qty': 1.0, 'Taxable Value': 1045.7627118644068, 'GST Rate': 0.18, 'IGST': 43.32203389830508, 'CGST': 0.0, 'SGST': 0.0, 'Invoice Value': 1234.0, 'TCS': 10.457627118644067, '_id': ObjectId('67d4459c2df68cfc0d8ac607')}

# %%
df = pd.DataFrame(list(db['Final_Report'].find()))

# %%
df
# Out:
#                            _id Marketplace    Invoice Number  \
# 0     67b1c837b039f7ed9cff8815    FLIPKART  FAHTK32200000001
# 1     67b1c837b039f7ed9cff8816    FLIPKART  FAHTK32200000002
# 2     67b1c837b039f7ed9cff8817    FLIPKART  FAHTK32200000003
# 3     67b1c837b039f7ed9cff8818    FLIPKART  RAF0JN2200000001
# 4     67b1c837b039f7ed9cff8819    FLIPKART  FAHTK32200000004
# ...                        ...         ...               ...
# 4067  67d4459c2df68cfc0d8ac603      MEESHO        dszv725C70
# 4068  67d4459c2df68cfc0d8ac604      MEESHO        dszv725C71
# 4069  67d4459c2df68cfc0d8ac605      MEESHO        dszv725C73
# 4070  67d4459c2df68cfc0d8ac606      MEESHO        dszv725C69
# 4071  67d4459c2df68cfc0d8ac607      MEESHO        dszv725C75
#
#             Invoice Date Party Name GSTN Period       FY Nature  \
# 0    2021-06-15 00:00:00         NA   NA    Jun  2021-22    B2C
# 1    2021-06-20 00:00:00         NA   NA    Jun  2021-22    B2C
# 2    2021-06-20 00:00:00         NA   NA    Jun  2021-22    B2C
# 3    2021-06-22 00:00:00         NA   NA    Jun  2021-22    B2C
# 4    2021-06-24 00:00:00         NA   NA    Jun  2021-22    B2C
# ...                  ...        ...  ...    ...      ...    ...
# 4067 2025-02-02 20:34:29         NA   NA    Feb  2024-25    B2C
# 4068 2025-02-05 21:40:06         NA   NA    Feb  2024-25    B2C
# 4069 2025-02-16 19:01:35         NA   NA    Feb  2024-25    B2C
# 4070 2025-02-01 14:14:32         NA   NA    Feb  2024-25    B2C
# 4071 2025-02-19 15:21:39         NA   NA    Feb  2024-25    B2C
#
#      Transaction Type     Destination  HSN Code  Qty  Taxable Value  GST Rate  \
# 0                Sale   Uttar Pradesh  35052000  1.0     174.580000      0.18
# 1                Sale       Telangana  35061000  1.0     143.220000      0.18
# 2                Sale          Odisha  35061000  1.0     154.240000      0.18
# 3              Return       Telangana  35061000  1.0    -143.220000      0.18
# 4                Sale         Gujarat  35061000  1.0     191.530000      0.18
# ...               ...             ...       ...  ...            ...       ...
# 4067        Cancelled     MAHARASHTRA    854449  1.0    1045.762712      0.18
# 4068        Cancelled     UTTARAKHAND    854449  1.0     500.847458      0.18
# 4069        Cancelled    CHHATTISGARH    854449  1.0     544.915254      0.18
# 4070        Cancelled  MADHYA PRADESH    854449  1.0     466.101695      0.18
# 4071        Cancelled    CHHATTISGARH    854449  1.0    1045.762712      0.18
#
#            IGST  CGST  SGST  Invoice Value        TCS
# 0     31.420000   0.0   0.0          206.0   1.750000
# 1     25.780000   0.0   0.0          169.0   1.430000
# 2     27.760000   0.0   0.0          182.0   1.540000
# 3    -25.780000   0.0   0.0         -169.0  -1.430000
# 4     34.470000   0.0   0.0          226.0   1.920000
# ...         ...   ...   ...            ...        ...
# 4067  43.322034   0.0   0.0         1234.0  10.457627
# 4068  43.322034   0.0   0.0          591.0   5.008475
# 4069  43.322034   0.0   0.0          643.0   5.449153
# 4070  43.322034   0.0   0.0          591.0   4.661017
# 4071  43.322034   0.0   0.0         1234.0  10.457627
#
# [4072 rows x 20 columns]
